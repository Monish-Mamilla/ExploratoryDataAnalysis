# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/weather2_data.csv",parse_dates=['day'])

# %%
df.head()
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01           32          6      Rain
# 1 2017-01-02       -99999          7     Sunny
# 2 2017-01-03           28     -99999      Snow
# 3 2017-01-04       -99999          7  no event
# 4 2017-01-05           32     -99999      Rain

# %%
df.set_index('day',inplace=True)

# %%
df.head()
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01           32          6      Rain
# 2017-01-02       -99999          7     Sunny
# 2017-01-03           28     -99999      Snow
# 2017-01-04       -99999          7  no event
# 2017-01-05           32     -99999      Rain

# %%
df.replace(to_replace=[-99999],value=np.nan)
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-02          NaN        7.0     Sunny
# 2017-01-03         28.0        NaN      Snow
# 2017-01-04          NaN        7.0  no event
# 2017-01-05         32.0        NaN      Rain
# 2017-01-06         31.0        2.0     Sunny
# 2017-01-06         34.0   -88888.0  no event

# %%
df.replace( {
    'temparature':-99999,
    'windspeed':-99999,
    'event':'no event'
},np.nan)
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32        6.0   Rain
# 2017-01-02       -99999        7.0  Sunny
# 2017-01-03           28        NaN   Snow
# 2017-01-04       -99999        7.0    NaN
# 2017-01-05           32        NaN   Rain
# 2017-01-06           31        2.0  Sunny
# 2017-01-06           34   -88888.0    NaN

# %%
df.replace({ -99999:np.nan, -88888:np.nan,
            'no event':'Sunny'})
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0  Sunny
# 2017-01-05         32.0        NaN   Rain
# 2017-01-06         31.0        2.0  Sunny
# 2017-01-06         34.0        NaN  Sunny
